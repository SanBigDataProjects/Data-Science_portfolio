# %%
#pip install yfinance
# !pip install --upgrade yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\Sam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: yfinance in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (2.2.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (4.2.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\sam\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %% [markdown]
# ###Problem Statement:
# #The goal of this project is to predict the stock price of Apple (AAPL) for the year 2021 using a Long Short-Term Memory (LSTM) model. LSTM is a type of Recurrent Neural Network (RNN) that excels at processing sequential data and capturing long-term dependencies. Given the sequential nature of stock prices, LSTM is an ideal choice for predicting future prices based on historical data. We will train the model using Apple’s stock data for the year 2021 and evaluate its performance using metrics like Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE). In addition, we’ll assess whether the model can predict future prices, specifically for 2022.

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError


# Download Apple stock data
data = yf.download('AAPL', start='2021-01-01', end='2021-12-31')
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  126.405243  130.507720  123.816772  130.419814  143301900
# 2021-01-05  127.968079  128.681140  125.447982  125.897308   97664900
# 2021-01-06  123.660477  128.007157  123.445584  124.754474  155088000
# 2021-01-07  127.880165  128.573686  124.891218  125.379608  109578200
# 2021-01-08  128.983932  129.550467  127.206184  129.355099  105158200

# %%
# Step 2: Data Preprocessing

# Normalize data using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[['Close']].values)
scaled_data

# Scaling the data helps LSTM models perform better, as they require normalized values.
# Out:
# array([[-0.94541019],
#        [-0.95941461],
#        [-0.95936923],
#        ...,
#        [ 1.10413878],
#        [ 1.17627144],
#        [ 1.18273694]])

# %%
# Function to create dataset with sequences for LSTM
def create_dataset(data, time_step=60):
    # Create sequences of data to predict next day's price based on 'time_step' previous days
    X, y = [], []
    for i in range(time_step, len(data)):
        X.append(data[i-time_step:i, 0])  # Sequence of `time_step` days
        y.append(data[i, 0])  # Next day's price
    return np.array(X), np.array(y)

# Create the dataset
time_step = 60  # Using 60 days to predict next day's price
X, y = create_dataset(scaled_data, time_step)

# The 'create_dataset' function prepares sequences of data for training the LSTM model.

# %%
# Split the data into training and test sets
train_size = int(len(X) * 0.75)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# Reshape data to be compatible with LSTM input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Step 3: Build the LSTM Model

# Initialize the model
# Initialize the LSTM model
model = Sequential()

# Add LSTM layer with 50 units
model.add(LSTM(units=50, return_sequences=False, input_shape=(X_train.shape[1], 1)))

# Add Dense layer for output
model.add(Dense(units=1))

# Compile the model with RMSE and MAE as additional metrics
model.compile(optimizer='adam', loss='mean_squared_error', metrics=[RootMeanSquaredError(), MeanAbsoluteError()])
# Out:
# C:\Users\Sam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model on the training data
history = model.fit(X_train, y_train, epochs=75, batch_size=32, validation_data=(X_test, y_test))

# Predict stock prices for training and test data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform the predictions to actual stock price values
train_predict_actual = scaler.inverse_transform(train_predict)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
test_predict_actual = scaler.inverse_transform(test_predict)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# Epoch 1/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.2820 - mean_absolute_error: 0.4224 - root_mean_squared_error: 0.5131 - val_loss: 0.1936 - val_mean_absolute_error: 0.3927 - val_root_mean_squared_error: 0.4400
# Epoch 2/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0048 - mean_absolute_error: 0.0521 - root_mean_squared_error: 0.0693 - val_loss: 0.0902 - val_mean_absolute_error: 0.2444 - val_root_mean_squared_error: 0.3003
# Epoch 3/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0322 - root_mean_squared_error: 0.0476 - val_loss: 0.0984 - val_mean_absolute_error: 0.2575 - val_root_mean_squared_error: 0.3136
# Epoch 4/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0308 - root_mean_squared_error: 0.0494 - val_loss: 0.0704 - val_mean_absolute_error: 0.2126 - val_root_mean_squared_error: 0.2653
# Epoch 5/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0299 - root_mean_squared_error: 0.0498 - val_loss: 0.0458 - val_mean_absolute_error: 0.1680 - val_root_mean_squared_error: 0.2141
# Epoch 6/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0282 - root_mean_squared_error: 0.0459 - val_loss: 0.0676 - val_mean_absolute_error: 0.2105 - val_root_mean_squared_error: 0.2599
# Epoch 7/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - root_mean_squared_error: 0.0426 - val_loss: 0.0670 - val_mean_absolute_error: 0.2109 - val_root_mean_squared_error: 0.2588
# Epoch 8/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0277 - root_mean_squared_error: 0.0463 - val_loss: 0.0471 - val_mean_absolute_error: 0.1726 - val_root_mean_squared_error: 0.2170
# Epoch 9/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0261 - root_mean_squared_error: 0.0439 - val_loss: 0.0363 - val_mean_absolute_error: 0.1497 - val_root_mean_squared_error: 0.1906
# Epoch 10/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0241 - root_mean_squared_error: 0.0385 - val_loss: 0.0399 - val_mean_absolute_error: 0.1585 - val_root_mean_squared_error: 0.1996
# Epoch 11/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0274 - root_mean_squared_error: 0.0443 - val_loss: 0.0428 - val_mean_absolute_error: 0.1660 - val_root_mean_squared_error: 0.2070
# Epoch 12/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0236 - root_mean_squared_error: 0.0389 - val_loss: 0.0420 - val_mean_absolute_error: 0.1653 - val_root_mean_squared_error: 0.2049
# Epoch 13/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0242 - root_mean_squared_error: 0.0384 - val_loss: 0.0390 - val_mean_absolute_error: 0.1587 - val_root_mean_squared_error: 0.1975
# Epoch 14/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0253 - root_mean_squared_error: 0.0424 - val_loss: 0.0232 - val_mean_absolute_error: 0.1177 - val_root_mean_squared_error: 0.1523
# Epoch 15/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0231 - root_mean_squared_error: 0.0382 - val_loss: 0.0181 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1344
# Epoch 16/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0236 - root_mean_squared_error: 0.0404 - val_loss: 0.0360 - val_mean_absolute_error: 0.1533 - val_root_mean_squared_error: 0.1898
# Epoch 17/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0234 - root_mean_squared_error: 0.0392 - val_loss: 0.0460 - val_mean_absolute_error: 0.1780 - val_root_mean_squared_error: 0.2145
# Epoch 18/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0239 - root_mean_squared_error: 0.0408 - val_loss: 0.0260 - val_mean_absolute_error: 0.1272 - val_root_mean_squared_error: 0.1614
# Epoch 19/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - root_mean_squared_error: 0.0417 - val_loss: 0.0187 - val_mean_absolute_error: 0.1052 - val_root_mean_squared_error: 0.1368
# Epoch 20/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0236 - root_mean_squared_error: 0.0380 - val_loss: 0.0211 - val_mean_absolute_error: 0.1129 - val_root_mean_squared_error: 0.1451
# Epoch 21/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0223 - root_mean_squared_error: 0.0374 - val_loss: 0.0229 - val_mean_absolute_error: 0.1190 - val_root_mean_squared_error: 0.1513
# Epoch 22/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0244 - root_mean_squared_error: 0.0402 - val_loss: 0.0254 - val_mean_absolute_error: 0.1273 - val_root_mean_squared_error: 0.1594
# Epoch 23/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0248 - root_mean_squared_error: 0.0405 - val_loss: 0.0350 - val_mean_absolute_error: 0.1539 - val_root_mean_squared_error: 0.1872
# Epoch 24/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0227 - root_mean_squared_error: 0.0366 - val_loss: 0.0210 - val_mean_absolute_error: 0.1142 - val_root_mean_squared_error: 0.1451
# Epoch 25/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0213 - root_mean_squared_error: 0.0348 - val_loss: 0.0131 - val_mean_absolute_error: 0.0872 - val_root_mean_squared_error: 0.1143
# Epoch 26/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0229 - root_mean_squared_error: 0.0372 - val_loss: 0.0214 - val_mean_absolute_error: 0.1159 - val_root_mean_squared_error: 0.1463
# Epoch 27/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0226 - root_mean_squared_error: 0.0379 - val_loss: 0.0181 - val_mean_absolute_error: 0.1052 - val_root_mean_squared_error: 0.1347
# Epoch 28/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0218 - root_mean_squared_error: 0.0352 - val_loss: 0.0159 - val_mean_absolute_error: 0.0977 - val_root_mean_squared_error: 0.1262
# Epoch 29/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0221 - root_mean_squared_error: 0.0364 - val_loss: 0.0219 - val_mean_absolute_error: 0.1181 - val_root_mean_squared_error: 0.1479
# Epoch 30/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0225 - root_mean_squared_error: 0.0372 - val_loss: 0.0208 - val_mean_absolute_error: 0.1147 - val_root_mean_squared_error: 0.1441
# Epoch 31/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0222 - root_mean_squared_error: 0.0371 - val_loss: 0.0155 - val_mean_absolute_error: 0.0967 - val_root_mean_squared_error: 0.1246
# Epoch 32/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0222 - root_mean_squared_error: 0.0357 - val_loss: 0.0196 - val_mean_absolute_error: 0.1115 - val_root_mean_squared_error: 0.1399
# Epoch 33/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0218 - root_mean_squared_error: 0.0346 - val_loss: 0.0175 - val_mean_absolute_error: 0.1046 - val_root_mean_squared_error: 0.1324
# Epoch 34/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0233 - root_mean_squared_error: 0.0375 - val_loss: 0.0177 - val_mean_absolute_error: 0.1053 - val_root_mean_squared_error: 0.1329
# Epoch 35/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0202 - root_mean_squared_error: 0.0332 - val_loss: 0.0151 - val_mean_absolute_error: 0.0959 - val_root_mean_squared_error: 0.1228
# Epoch 36/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0207 - root_mean_squared_error: 0.0348 - val_loss: 0.0230 - val_mean_absolute_error: 0.1237 - val_root_mean_squared_error: 0.1518
# Epoch 37/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - root_mean_squared_error: 0.0332 - val_loss: 0.0185 - val_mean_absolute_error: 0.1084 - val_root_mean_squared_error: 0.1360
# Epoch 38/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - root_mean_squared_error: 0.0334 - val_loss: 0.0112 - val_mean_absolute_error: 0.0814 - val_root_mean_squared_error: 0.1056
# Epoch 39/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0202 - root_mean_squared_error: 0.0327 - val_loss: 0.0185 - val_mean_absolute_error: 0.1092 - val_root_mean_squared_error: 0.1361
# Epoch 40/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0196 - root_mean_squared_error: 0.0317 - val_loss: 0.0147 - val_mean_absolute_error: 0.0952 - val_root_mean_squared_error: 0.1211
# Epoch 41/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0198 - root_mean_squared_error: 0.0327 - val_loss: 0.0162 - val_mean_absolute_error: 0.1013 - val_root_mean_squared_error: 0.1274
# Epoch 42/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0208 - root_mean_squared_error: 0.0356 - val_loss: 0.0121 - val_mean_absolute_error: 0.0856 - val_root_mean_squared_error: 0.1100
# Epoch 43/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0197 - root_mean_squared_error: 0.0322 - val_loss: 0.0101 - val_mean_absolute_error: 0.0776 - val_root_mean_squared_error: 0.1005
# Epoch 44/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0197 - root_mean_squared_error: 0.0328 - val_loss: 0.0147 - val_mean_absolute_error: 0.0959 - val_root_mean_squared_error: 0.1213
# Epoch 45/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.3433e-04 - mean_absolute_error: 0.0188 - root_mean_squared_error: 0.0305 - val_loss: 0.0122 - val_mean_absolute_error: 0.0864 - val_root_mean_squared_error: 0.1104
# Epoch 46/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0201 - root_mean_squared_error: 0.0325 - val_loss: 0.0092 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0958
# Epoch 47/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.6323e-04 - mean_absolute_error: 0.0187 - root_mean_squared_error: 0.0309 - val_loss: 0.0084 - val_mean_absolute_error: 0.0706 - val_root_mean_squared_error: 0.0919
# Epoch 48/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0192 - root_mean_squared_error: 0.0321 - val_loss: 0.0123 - val_mean_absolute_error: 0.0875 - val_root_mean_squared_error: 0.1109
# Epoch 49/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0199 - root_mean_squared_error: 0.0330 - val_loss: 0.0122 - val_mean_absolute_error: 0.0868 - val_root_mean_squared_error: 0.1103
# Epoch 50/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.7460e-04 - mean_absolute_error: 0.0185 - root_mean_squared_error: 0.0294 - val_loss: 0.0103 - val_mean_absolute_error: 0.0791 - val_root_mean_squared_error: 0.1014
# Epoch 51/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.3912e-04 - mean_absolute_error: 0.0182 - root_mean_squared_error: 0.0306 - val_loss: 0.0105 - val_mean_absolute_error: 0.0803 - val_root_mean_squared_error: 0.1027
# Epoch 52/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.9952e-04 - mean_absolute_error: 0.0183 - root_mean_squared_error: 0.0300 - val_loss: 0.0095 - val_mean_absolute_error: 0.0758 - val_root_mean_squared_error: 0.0975
# Epoch 53/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0194 - root_mean_squared_error: 0.0324 - val_loss: 0.0152 - val_mean_absolute_error: 0.1000 - val_root_mean_squared_error: 0.1233
# Epoch 54/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.0888e-04 - mean_absolute_error: 0.0184 - root_mean_squared_error: 0.0301 - val_loss: 0.0079 - val_mean_absolute_error: 0.0681 - val_root_mean_squared_error: 0.0887
# Epoch 55/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0188 - root_mean_squared_error: 0.0320 - val_loss: 0.0124 - val_mean_absolute_error: 0.0889 - val_root_mean_squared_error: 0.1112
# Epoch 56/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0855e-04 - mean_absolute_error: 0.0180 - root_mean_squared_error: 0.0284 - val_loss: 0.0077 - val_mean_absolute_error: 0.0674 - val_root_mean_squared_error: 0.0877
# Epoch 57/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.4950e-04 - mean_absolute_error: 0.0178 - root_mean_squared_error: 0.0307 - val_loss: 0.0065 - val_mean_absolute_error: 0.0619 - val_root_mean_squared_error: 0.0809
# Epoch 58/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9867e-04 - mean_absolute_error: 0.0184 - root_mean_squared_error: 0.0315 - val_loss: 0.0083 - val_mean_absolute_error: 0.0704 - val_root_mean_squared_error: 0.0909
# Epoch 59/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.9133e-04 - mean_absolute_error: 0.0186 - root_mean_squared_error: 0.0298 - val_loss: 0.0159 - val_mean_absolute_error: 0.1038 - val_root_mean_squared_error: 0.1262
# Epoch 60/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.5933e-04 - mean_absolute_error: 0.0182 - root_mean_squared_error: 0.0293 - val_loss: 0.0081 - val_mean_absolute_error: 0.0696 - val_root_mean_squared_error: 0.0898
# Epoch 61/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.0730e-04 - mean_absolute_error: 0.0193 - root_mean_squared_error: 0.0300 - val_loss: 0.0081 - val_mean_absolute_error: 0.0696 - val_root_mean_squared_error: 0.0898
# Epoch 62/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4980e-04 - mean_absolute_error: 0.0172 - root_mean_squared_error: 0.0291 - val_loss: 0.0077 - val_mean_absolute_error: 0.0679 - val_root_mean_squared_error: 0.0877
# Epoch 63/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.1032e-04 - mean_absolute_error: 0.0171 - root_mean_squared_error: 0.0284 - val_loss: 0.0096 - val_mean_absolute_error: 0.0774 - val_root_mean_squared_error: 0.0981
# Epoch 64/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.3814e-04 - mean_absolute_error: 0.0193 - root_mean_squared_error: 0.0306 - val_loss: 0.0080 - val_mean_absolute_error: 0.0693 - val_root_mean_squared_error: 0.0894
# Epoch 65/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2888e-04 - mean_absolute_error: 0.0169 - root_mean_squared_error: 0.0287 - val_loss: 0.0106 - val_mean_absolute_error: 0.0819 - val_root_mean_squared_error: 0.1028
# Epoch 66/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0024e-04 - mean_absolute_error: 0.0171 - root_mean_squared_error: 0.0283 - val_loss: 0.0102 - val_mean_absolute_error: 0.0809 - val_root_mean_squared_error: 0.1012
# Epoch 67/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.1504e-04 - mean_absolute_error: 0.0181 - root_mean_squared_error: 0.0302 - val_loss: 0.0097 - val_mean_absolute_error: 0.0785 - val_root_mean_squared_error: 0.0986
# Epoch 68/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.8588e-04 - mean_absolute_error: 0.0180 - root_mean_squared_error: 0.0296 - val_loss: 0.0072 - val_mean_absolute_error: 0.0655 - val_root_mean_squared_error: 0.0850
# Epoch 69/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0542e-04 - mean_absolute_error: 0.0169 - root_mean_squared_error: 0.0283 - val_loss: 0.0056 - val_mean_absolute_error: 0.0573 - val_root_mean_squared_error: 0.0746
# Epoch 70/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.3633e-04 - mean_absolute_error: 0.0162 - root_mean_squared_error: 0.0271 - val_loss: 0.0072 - val_mean_absolute_error: 0.0654 - val_root_mean_squared_error: 0.0847
# Epoch 71/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2453e-04 - mean_absolute_error: 0.0175 - root_mean_squared_error: 0.0286 - val_loss: 0.0087 - val_mean_absolute_error: 0.0731 - val_root_mean_squared_error: 0.0932
# Epoch 72/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6796e-04 - mean_absolute_error: 0.0171 - root_mean_squared_error: 0.0276 - val_loss: 0.0127 - val_mean_absolute_error: 0.0924 - val_root_mean_squared_error: 0.1127
# Epoch 73/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.5129e-04 - mean_absolute_error: 0.0170 - root_mean_squared_error: 0.0274 - val_loss: 0.0054 - val_mean_absolute_error: 0.0559 - val_root_mean_squared_error: 0.0735
# Epoch 74/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.7718e-04 - mean_absolute_error: 0.0173 - root_mean_squared_error: 0.0295 - val_loss: 0.0085 - val_mean_absolute_error: 0.0730 - val_root_mean_squared_error: 0.0923
# Epoch 75/75
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.9399e-04 - mean_absolute_error: 0.0156 - root_mean_squared_error: 0.0263 - val_loss: 0.0082 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0907
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# Calculate RMSE for training and testing
train_rmse = np.sqrt(mean_squared_error(y_train_actual, train_predict_actual))
test_rmse = np.sqrt(mean_squared_error(y_test_actual, test_predict_actual))

print(f'Train RMSE: {train_rmse}')
print(f'Test RMSE: {test_rmse}')
# Out:
# Train RMSE: 1.2981958887932192
# Test RMSE: 4.43686609497362

# %%
# Plot training & validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot training & validation RMSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['root_mean_squared_error'], label='Training RMSE')
plt.plot(history.history['val_root_mean_squared_error'], label='Validation RMSE')
plt.title('Training and Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
# Plot Actual vs Predicted prices
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual Prices')
plt.plot(test_predict_actual, label='Predicted Prices')
plt.title('Actual vs Predicted Apple Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Download Apple stock data for 2022
data_2022 = yf.download('AAPL', start='2022-01-01', end='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Normalize 2022 data using the same scaler
scaled_data_2022 = scaler.transform(data_2022[['Close']].values)

# Create dataset with sequences for LSTM for 2022
X_2022, y_2022 = create_dataset(scaled_data_2022, time_step)

# Reshape data for LSTM input
X_2022 = X_2022.reshape(X_2022.shape[0], X_2022.shape[1], 1)

# %%
# Predict stock prices for 2022
test_predict_2022 = model.predict(X_2022)

# Inverse transform the predictions to actual stock price values
test_predict_actual_2022 = scaler.inverse_transform(test_predict_2022)
y_test_actual_2022 = scaler.inverse_transform(y_2022.reshape(-1, 1))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Calculate RMSE for 2022
test_rmse_2022 = np.sqrt(mean_squared_error(y_test_actual_2022, test_predict_actual_2022))
print(f'Test RMSE for 2022: {test_rmse_2022}')
# Out:
# Test RMSE for 2022: 4.5590572060799985

# %%
# Plot Actual vs Predicted Prices for 2022
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual_2022, label='Actual Prices')
plt.plot(test_predict_actual_2022, label='Predicted Prices')
plt.title('Actual vs Predicted Apple Stock Prices (2022)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Summary:
# In this project, I built a Long Short-Term Memory (LSTM) model to predict Apple's stock price for the year 2021. The model was trained using historical stock data from January 1, 2021, to December 31, 2021. The goal was to predict the next day's stock price based on the previous 60 days of data.
#
# # Key Findings:
# Model Performance:
#
# The Training RMSE was 1.29, which indicates that the model fit the training data well.
# The Test RMSE for 2021 was 4.44, suggesting that the model struggles to generalize to unseen data, a common challenge in stock price prediction.
#
# ## Loss and RMSE Visualization:
#
# The Training Loss consistently decreased, but the Validation Loss showed fluctuations, which suggests potential overfitting. The Training RMSE decreased steadily, while the Validation RMSE exhibited some oscillations, indicating room for improvement in generalization.
# Prediction Accuracy:
#
# The Actual vs. Predicted Prices graph demonstrated that the model captured the overall trend of Apple's stock price but had some deviations, especially during more volatile periods. This is typical in stock price forecasting due to market unpredictability.
#
# ## Testing on 2022 Data:
#
# After training the model on 2021 data, I tested it on 2022 data. The Test RMSE for 2022 was 4.56, indicating that the model had similar performance on data from 2022. This shows that the model can follow trends in stock prices, but it still struggles with exact predictions, especially in more volatile periods.
